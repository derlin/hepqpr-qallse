# %% [markdown]
# This notebook runs a `Qallse` model in simulation mode and shows how to simply visualize the results using utilities defined in module `qallse.plotting`.

# %% [markdown]
# # Import and setup

# %%
# import modules
import pandas as pd
import numpy as np

from qallse.plotting import *
from qallse import *
from qallse.dsmaker import create_dataset

# initialise the plotting module in "notebook" mode
set_notebook_mode()

# initialise the logging module
import logging
logging.basicConfig()
fmt = logging.Formatter("%(asctime)s.%(msecs)03d %(levelname)s %(name)s: %(message)s", datefmt='%H:%M:%S')
for handler in logging.getLogger().handlers: handler.setFormatter(fmt)
logging.getLogger('hepqpr').setLevel(logging.DEBUG)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Define run config

# %%
# == DATASET CONFIG

dsmaker_config = dict(
    density=.01, # 1% 
)

# == INPUT CONFIG

# whether or not to add missing doublets to the input
add_missing = True 

# == RUN CONFIG

model_class = QallseD0 # model class to use
extra_config = dict() # configuration arguments overriding the defaults

# %% [markdown]
# # Generate the data

# %%
import tempfile

tempdir = tempfile.TemporaryDirectory()
print(f'using {tempdir.name}')
metas, path = create_dataset(output_path=tempdir.name, gen_doublets=True, **dsmaker_config)
# Out:
# using /var/folders/qp/grrqv98s1c37f8bxtkblfpcr0000gn/T/tmpra3o223v
# 17:46:22.850 DEBUG qallse.dsmaker.dsmaker: Loaded 120939 hits from /Users/lin/git/quantum-annealing-project/project-2/src/hepqpr/qallse/dsmaker/data/event000001000.
# 17:46:22.873 DEBUG qallse.dsmaker.dsmaker: Filtered hits from barrel. Remaining hits: 65518.
# 17:46:22.914 DEBUG qallse.dsmaker.dsmaker: Dropped double hits. Remaining hits: 55446.
# 17:46:22.935 DEBUG qallse.dsmaker.dsmaker: High Pt hits: 32302/524
# 17:46:22.967 DEBUG qallse.dsmaker.dsmaker:   num_hits=524
# 17:46:22.967 DEBUG qallse.dsmaker.dsmaker:   num_tracks=81
# 17:46:22.968 DEBUG qallse.dsmaker.dsmaker:   num_important_tracks=4
# 17:46:22.968 DEBUG qallse.dsmaker.dsmaker:   num_noise=130
# 17:46:22.969 DEBUG qallse.dsmaker.dsmaker:   random_seed=1547862382
# 17:46:22.969 DEBUG qallse.dsmaker.dsmaker:   time=2019-01-18T17:46:22.967102
# 17:46:23.219 INFO qallse.dsmaker.dsmaker: Doublets (len=1352) generated in f/var/folders/qp/grrqv98s1c37f8bxtkblfpcr0000gn/T/tmpra3o223v/ez-0.01_hpt-1.0/event000001000.

# %%
with open(path + '-meta.json') as f:
    print(f.read())
# Out:
# {
#     "num_hits": 524,
#     "num_tracks": 81,
#     "num_important_tracks": 4,
#     "num_noise": 130,
#     "random_seed": 1547862382,
#     "time": "2019-01-18T17:46:22.967102",
#     "params": {
#         "input_path": "/Users/lin/git/quantum-annealing-project/project-2/src/hepqpr/qallse/dsmaker/data/event000001000",
#         "output_path": "/var/folders/qp/grrqv98s1c37f8bxtkblfpcr0000gn/T/tmpra3o223v",
#         "density": 0.01,
#         "high_pt_cut": 1.0,
#         "double_hits_ok": false,
#         "gen_doublets": true,
#         "prefix": null,
#         "random_seed": null,
#         "phi_bounds": null,
#         "min_hits_per_track": 5
#     }
# }

# %% [markdown]
# # Execute the model

# %% [markdown]
# ## Load the data

# %%
# load data
dw = DataWrapper.from_path(path)
doublets = pd.read_csv(path + '-doublets.csv')
if add_missing:
    doublets = dw.add_missing_doublets(doublets)
else:
    p, r, ms = dw.compute_score(doublets)
    print(f'got {len(doublets)}.')
    print(f'  Input precision (%): {p*100:.4f}, recall (%): {r*100:.4f}, missing: {len(ms)}')
# Out:
# got 1352 doublets.
#   Input precision (%): 3.2200, recall (%): 100.0000

# %% [markdown]
# ## Build the model

# %%
# %%time

# instantiate qallse
model = model_class(dw, **extra_config)
# build the qubo
model.build_model(doublets=doublets)
Q = model.to_qubo()
# Out:
# 17:46:33.161 DEBUG qallse.qallse_d0: using config:
# 17:46:33.162 DEBUG qallse.qallse_d0:     beamspot_center: (0, 0, 0)
# 17:46:33.163 DEBUG qallse.qallse_d0:     beamspot_width: 27.5
# 17:46:33.163 DEBUG qallse.qallse_d0:     cheat: False
# 17:46:33.164 DEBUG qallse.qallse_d0:     d0_denom: 3.0
# 17:46:33.165 DEBUG qallse.qallse_d0:     d0_factor: 0.5
# 17:46:33.165 DEBUG qallse.qallse_d0:     max_layer_span: 2
# 17:46:33.166 DEBUG qallse.qallse_d0:     min_qplet_path: 2
# 17:46:33.166 DEBUG qallse.qallse_d0:     num_multiplier: -1
# 17:46:33.167 DEBUG qallse.qallse_d0:     qplet_max_dcurv: 0.0001
# 17:46:33.167 DEBUG qallse.qallse_d0:     qplet_max_strength: -0.2
# 17:46:33.168 DEBUG qallse.qallse_d0:     qubo_bias_weight: 0
# 17:46:33.168 DEBUG qallse.qallse_d0:     qubo_conflict_strength: 1
# 17:46:33.169 DEBUG qallse.qallse_d0:     rz_power: 1
# 17:46:33.169 DEBUG qallse.qallse_d0:     strength_bounds: None
# 17:46:33.169 DEBUG qallse.qallse_d0:     tplet_max_curv: 0.0008
# 17:46:33.170 DEBUG qallse.qallse_d0:     tplet_max_drz: 0.1
# 17:46:33.170 DEBUG qallse.qallse_d0:     volayer_power: 2
# 17:46:33.171 DEBUG qallse.qallse_d0:     xy_power: 1
# 17:46:33.171 DEBUG qallse.qallse_d0:     xy_relative_strength: 0.5
# 17:46:33.172 DEBUG qallse.qallse_d0:     z0_denom: 1.0
# 17:46:33.172 DEBUG qallse.qallse_d0:     z0_factor: 0.1
# 17:46:33.238 INFO qallse.qallse_d0: created 810 doublets.
# 17:46:33.263 INFO qallse.qallse_d0: created 267 triplets.
# 17:46:33.268 INFO qallse.qallse_d0: created 201 quadruplets.
# 17:46:33.268 INFO qallse.qallse_d0: Model built in 0.08s. doublets: 0, triplets: 0, quadruplets: 201
# 17:46:33.272 INFO qallse.qallse_d0: MaxPath done in 0.01s. doublets: 159, triplets: 187, quadruplets: 192 (dropped 9)
# 17:46:33.292 INFO qallse.qallse_d0: Qubo generated in 0.03s. Size: 852. Vars: 187, excl. couplers: 473, incl. couplers: 192
# CPU times: user 127 ms, sys: 10.6 ms, total: 138 ms
# Wall time: 132 ms

# %% [markdown]
# ## Sample the QUBO
#
# Here, we use [_qbsolv_](https://github.com/dwavesystems/qbsolv) with default arguments. This means only classical algorithms.

# %%
# %%time
# execute the qubo
response = model.sample_qubo(Q=Q)
# Out:
# 17:46:38.267 INFO qallse.qallse_d0: QUBO of size 852 sampled in 0.76s (seed 2025012979).
# CPU times: user 383 ms, sys: 4 ms, total: 387 ms
# Wall time: 387 ms

# %% [markdown]
# ## Parse the results

# %%
# get all output doublets
all_doublets = model.process_sample(next(response.samples()))
# recreate tracks and resolve remaining conflicts
final_tracks, final_doublets = TrackRecreaterD().process_results(all_doublets)
# Out:
# 17:46:40.892 INFO qallse.track_recreater: Found 0 conflicting doublets

# %% [markdown]
# # Evaluate the results

# %% [markdown]
# ## Print statistics and scores

# %%
# stats about the qbsolv run
en0 = dw.compute_energy(Q)
en = response.record.energy[0]

print(f'SAMPLE -- energy: {en:.4f}, ideal: {en0:.4f} (diff: {en-en0:.6f})')
occs = response.record.num_occurrences
print(f'          best sample occurrence: {occs[0]}/{occs.sum()}')

# scores
p, r, missings = dw.compute_score(final_doublets)
print(f'SCORE  -- precision (%): {p * 100}, recall (%): {r * 100}, missing: {len(missings)}')
trackml_score = dw.compute_trackml_score(final_tracks)
print(f'          tracks found: {len(final_tracks)}, trackml score (%): {trackml_score * 100}')
# Out:
# SAMPLE -- energy: -52.6204, ideal: -52.6204 (diff: 0.000000)
#           best sample occurrence: 27/56
# SCORE  -- precision (%): 100.0, recall (%): 100.0, missing: 0
#           tracks found: 14, trackml score (%): 100.0

# %% [markdown]
# ### Plot the results
#
# You have the following at your disposal:
# ```python
# iplot_results(dw, final_doublets, missings, dims=list('xy'))
# iplot_results_tracks(dw, final_doublets, missings, dims=list('zr'))
# iplot_results_any(dw, dw.real_doublets, dims=list('xy'))
# ```
#
# For 3D plots, simply define `dims` as 3-dimensional. For example:
# ```python
# iplot_results(dw, final_doublets, missings, dims=list('zxy'))
# ```

# %%
iplot_results(dw, final_doublets, missings, dims=list('xy'))
# Out:
# <div id="e427ce32-3e82-4013-93f9-cf658a3b0650" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e427ce32-3e82-4013-93f9-cf658a3b0650", [{"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": true, "text": ["18172", "27054"], "x": [-32.8382, -73.109], "y": [-1.33684, -2.11052], "type": "scatter", "uid": "211314fc-633b-44b3-a717-442618c30cbe"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["27054", "33801"], "x": [-73.109, -117.111], "y": [-2.11052, -1.73531], "type": "scatter", "uid": "6d34b1eb-0fa0-45cb-b8c2-48e012150c6a"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["33801", "39924"], "x": [-117.111, -173.481], "y": [-1.73531, 0.585159], "type": "scatter", "uid": "1aa4db4c-e1ad-4e1e-b049-4ee34a383e1c"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["39924", "71990"], "x": [-173.481, -260.587], "y": [0.585159, 7.88282], "type": "scatter", "uid": "8b3bf191-75b5-44c8-ac07-afec057c084b"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["24007", "32210"], "x": [31.9707, 71.6784], "y": [-0.258168, -1.73583], "type": "scatter", "uid": "65fe5fab-5b71-4909-9ac6-3ec3363e5f4e"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["32210", "39147"], "x": [71.6784, 115.366], "y": [-1.73583, -4.82506], "type": "scatter", "uid": "7fc50bb9-36e2-4e37-90f6-593d6e011575"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["39147", "77613"], "x": [115.366, 256.564], "y": [-4.82506, -25.181], "type": "scatter", "uid": "6aa8084b-51a4-489e-8ec6-d919afe34361"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["77613", "85026"], "x": [256.564, 359.6880000000001], "y": [-25.181, -50.5526], "type": "scatter", "uid": "8bb25efe-92d6-42c9-bf02-0c61c69274a5"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["18377", "27176"], "x": [-9.83741, -20.7884], "y": [-30.9344, -69.1677], "type": "scatter", "uid": "5425e432-6659-4613-bdcf-6ab2896d0aa4"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["27176", "34269"], "x": [-20.7884, -31.3417], "y": [-69.1677, -111.015], "type": "scatter", "uid": "20618a52-f469-43e1-b2a7-0ed26eeabf6e"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["34269", "40292"], "x": [-31.3417, -43.0161], "y": [-111.015, -166.56400000000005], "type": "scatter", "uid": "b45bbc79-1a0a-4586-9e22-47b7bd65f3ae"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["40 ...

# %%
iplot_results(dw, final_doublets, missings, dims=list('zr'))
# Out:
# <div id="29b6fd03-213d-49a3-ae6e-0486f2577f50" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("29b6fd03-213d-49a3-ae6e-0486f2577f50", [{"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": true, "text": ["18172", "27054"], "x": [-79.8381, -186.68400000000003], "y": [32.865400049681426, 73.13945703702208], "type": "scatter", "uid": "e5607039-003b-40b2-8f4e-3adba46c1fd2"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["27054", "33801"], "x": [-186.68400000000003, -303.539], "y": [73.13945703702208, 117.1238559038939], "type": "scatter", "uid": "b0105efe-1839-436f-b736-06fcc2521b16"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["33801", "39924"], "x": [-303.539, -453.227], "y": [117.1238559038939, 173.4819868806421], "type": "scatter", "uid": "92fe7154-074b-4764-b85b-29b523cd015b"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["39924", "71990"], "x": [-453.227, -686.2], "y": [173.4819868806421, 260.70620134579156], "type": "scatter", "uid": "f7eb8b0d-3c25-48cb-aafd-54e6ce67d62f"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["24007", "32210"], "x": [100.707, 213.125], "y": [31.97174235487056, 71.69941514649126], "type": "scatter", "uid": "3c24ff18-9cbf-4993-913c-59439b88f7fb"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["32210", "39147"], "x": [213.125, 336.8780000000001], "y": [71.69941514649126, 115.46685740940384], "type": "scatter", "uid": "9ccfabc0-8ae2-4ccf-88b1-49a4076507bc"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["39147", "77613"], "x": [336.8780000000001, 740.8], "y": [115.46685740940384, 257.7967588178719], "type": "scatter", "uid": "26ffce92-0097-4736-af1a-885970d9d8be"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["77613", "85026"], "x": [740.8, 1042.6], "y": [257.7967588178719, 363.2231032172376], "type": "scatter", "uid": "0e6ed8f3-6db4-4395-8929-5120443cc081"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["18377", "27176"], "x": [-77.2759, -160.22799999999995], "y": [32.46092634026484, 72.22415314733708], "type": "scatter", "uid": "f35ce93f-7589-435f-aa09-690a7a26525f"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["27176", "34269"], "x": [-160.22799999999995, -250.531], "y": [72.22415314733708, 115.35437739370795], "type": "scatter", "uid": "2d3175ed-f7ad-4f3e-a5aa-5c3c14ccbfa3"}, {"hoverinfo": "name+text", "legendgroup": "real_unfocused", "line": {"color": "darkseagreen", "width": 1}, "name": "real_unfocused", "opacity": 1, "showlegend": false, "text": ["34269", "40292"], "x": [-250.531, -369.436], "y": [115.35437739370795, 172.02892476327932], "t ...

# %%
iplot_results_tracks(dw, final_tracks, dims=list('zxy'))
# Out:
# <div id="aa1b88ec-1425-467c-8f84-78033d5de434" style="height: 900px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aa1b88ec-1425-467c-8f84-78033d5de434", [{"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T0: real", "opacity": 1, "showlegend": true, "text": ["18172", "27054", "33801", "39924", "71990"], "x": [-79.8381, -186.68400000000003], "y": [-32.8382, -73.109], "z": [-1.33684, -2.11052], "type": "scatter3d", "uid": "78951caa-d80a-4e62-a54c-bfb8b2d11931"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T0: real", "opacity": 1, "showlegend": false, "text": ["18172", "27054", "33801", "39924", "71990"], "x": [-186.68400000000003, -303.539], "y": [-73.109, -117.111], "z": [-2.11052, -1.73531], "type": "scatter3d", "uid": "c64e08c8-a935-41a0-9661-9bbf5cb58ef7"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T0: real", "opacity": 1, "showlegend": false, "text": ["18172", "27054", "33801", "39924", "71990"], "x": [-303.539, -453.227], "y": [-117.111, -173.481], "z": [-1.73531, 0.585159], "type": "scatter3d", "uid": "c43439ad-315e-49fb-b7ce-8b73d6aefdfa"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T0: real", "opacity": 1, "showlegend": false, "text": ["18172", "27054", "33801", "39924", "71990"], "x": [-453.227, -686.2], "y": [-173.481, -260.587], "z": [0.585159, 7.88282], "type": "scatter3d", "uid": "3bd02509-4538-486a-adf9-876e4a0f99d4"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T1: real", "opacity": 1, "showlegend": false, "text": ["24007", "32210", "39147", "77613", "85026"], "x": [100.707, 213.125], "y": [31.9707, 71.6784], "z": [-0.258168, -1.73583], "type": "scatter3d", "uid": "0a4b98e0-4559-4cd3-8096-565562a4f06d"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T1: real", "opacity": 1, "showlegend": false, "text": ["24007", "32210", "39147", "77613", "85026"], "x": [213.125, 336.8780000000001], "y": [71.6784, 115.366], "z": [-1.73583, -4.82506], "type": "scatter3d", "uid": "21f7a8fd-df83-48b9-baf3-8c37f3d6663e"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T1: real", "opacity": 1, "showlegend": false, "text": ["24007", "32210", "39147", "77613", "85026"], "x": [336.8780000000001, 740.8], "y": [115.366, 256.564], "z": [-4.82506, -25.181], "type": "scatter3d", "uid": "e579d036-bf91-485f-9cfa-59df204edd39"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T1: real", "opacity": 1, "showlegend": false, "text": ["24007", "32210", "39147", "77613", "85026"], "x": [740.8, 1042.6], "y": [256.564, 359.6880000000001], "z": [-25.181, -50.5526], "type": "scatter3d", "uid": "41cdfe68-cefb-49a3-a2bf-e6d8b8c80495"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T2: real", "opacity": 1, "showlegend": false, "text": ["18377", "27176", "34269", "40292", "72360", "79014", "85192"], "x": [-77.2759, -160.22799999999995], "y": [-9.83741, -20.7884], "z": [-30.9344, -69.1677], "type": "scatter3d", "uid": "2ae529a7-1410-46d4-8b3d-3887e35b9791"}, {"hoverinfo": "name+text", "legendgroup": "True", "line": {"color": "darkseagreen", "width": 1}, "marker": {"size": 3}, "name": "T2: real", "opacity": 1, "showlegend": false, "text": ["18377", "27176",  ...
